# %%
# %matplotlib inline

from __future__ import print_function
from __future__ import division

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# random forest models modified. changed criterion to absolute error

# %%
def preprocess_data(features, labels=None):
    if labels is not None:
        features = features.join(labels)
    features.reset_index(inplace=True)
    features.set_index('week_start_date',inplace=True)
    features = features.drop('year', axis=1)
    features = features.interpolate(method="quadratic")
    if labels is not None:
        return features.drop('total_cases', axis=1), features['total_cases']
    else:
        return features

def get_data(features_path, labels_path=None):
    if labels_path is not None:
        labels = pd.read_csv(labels_path,
                           index_col=[0,1,2])

    features = pd.read_csv(features_path,
                             index_col=[0,1,2],
                             parse_dates=['week_start_date'])

    # Separate data for San Juan
    sj_features = features.loc['sj']
    if labels_path is not None:
        sj_labels = labels.loc['sj']

    # Separate data for Iquitos
    iq_features = features.loc['iq']
    if labels_path is not None:
        iq_labels = labels.loc['iq']

    if labels_path is not None:
        sj_f, sj_l = preprocess_data(sj_features, sj_labels)
        iq_f, iq_l = preprocess_data(iq_features, iq_labels)
        return sj_f, sj_l, iq_f, iq_l

    return preprocess_data(sj_features, None), preprocess_data(iq_features, None)

# %%
sj_X_train, sj_y_train, iq_X_train, iq_y_train = get_data('dengue_features_train.csv',
                                                        'dengue_labels_train.csv')

# %% [markdown]
# # load the provided data
# train_features = pd.read_csv('dengue_features_train.csv',
#                              index_col=[0,1,2],
#                              parse_dates=['week_start_date'])
#
# train_labels = pd.read_csv('dengue_labels_train.csv',
#                            index_col=[0,1,2])

# %% [markdown]
# # Separate data for San Juan
# sj_train_features = train_features.loc['sj']
# sj_train_labels = train_labels.loc['sj']
#
# sj_X_train, sj_y_train = preprocess_data(sj_train_features,sj_train_labels)
#
# # Separate data for Iquitos
# iq_train_features = train_features.loc['iq']
# iq_train_labels = train_labels.loc['iq']
#
# iq_X_train, iq_y_train = preprocess_data(iq_train_features,iq_train_labels)

# %%
#split data in train and test
sj_X_train, sj_X_test, sj_y_train, sj_y_test = train_test_split(
    sj_X_train, sj_y_train, test_size=0.3, shuffle=False)

iq_X_train, iq_X_test, iq_y_train, iq_y_test = train_test_split(
iq_X_train, iq_y_train, test_size=0.3, shuffle=False)

# %%
sj_X_train.describe().transpose()
# Out:
#                                        count        mean        std  \
# weekofyear                             655.0   26.810687  14.858483
# ndvi_ne                                655.0    0.086158   0.096638
# ndvi_nw                                655.0    0.084960   0.106930
# ndvi_se                                655.0    0.170185   0.094370
# ndvi_sw                                655.0    0.163893   0.063279
# precipitation_amt_mm                   655.0   34.365767  41.398842
# reanalysis_air_temp_k                  655.0  299.020389   1.181711
# reanalysis_avg_temp_k                  655.0  299.128194   1.159116
# reanalysis_dew_point_temp_k            655.0  295.064769   1.568129
# reanalysis_max_air_temp_k              655.0  301.255595   1.199172
# reanalysis_min_air_temp_k              655.0  297.200063   1.269514
# reanalysis_precip_amt_kg_per_m2        655.0   32.094034  37.156531
# reanalysis_relative_humidity_percent   655.0   79.026845   3.424901
# reanalysis_sat_precip_amt_mm           655.0   34.365767  41.398842
# reanalysis_specific_humidity_g_per_kg  655.0   16.506448   1.549314
# reanalysis_tdtr_k                      655.0    2.436001   0.479500
# station_avg_temp_c                     655.0   27.050948   1.364318
# station_diur_temp_rng_c                655.0    6.864519   0.822225
# station_max_temp_c                     655.0   31.717557   1.629287
# station_min_temp_c                     655.0   22.587281   1.490391
# station_precip_mm                      655.0   25.088784  27.567897
#
#                                               min         25%         50%  \
# weekofyear                               1.000000   14.000000   27.000000
# ndvi_ne                                 -0.290200    0.032292    0.082800
# ndvi_nw                                 -0.567938    0.044733    0.085600
# ndvi_se                                 -0.556810    0.140464    0.177643
# ndvi_sw                                 -0.111362    0.129112    0.167943
# precipitation_amt_mm                   -15.492810    0.705000   21.530000
# reanalysis_air_temp_k                  295.938571  298.015714  299.215714
# reanalysis_avg_temp_k                  296.114286  298.160714  299.314286
# reanalysis_dew_point_temp_k            289.642857  293.820714  295.447143
# reanalysis_max_air_temp_k              298.200000  300.400000  301.400000
# reanalysis_min_air_temp_k              292.600000  296.200000  297.500000
# reanalysis_precip_amt_kg_per_m2          0.000000   12.200000   22.370000
# reanalysis_relative_humidity_percent    66.735714   76.890000   79.177143
# reanalysis_sat_precip_amt_mm           -15.492810    0.705000   21.530000
# reanalysis_specific_humidity_g_per_kg   11.715714   15.217857   16.831429
# reanalysis_tdtr_k                        1.357143    2.085714    2.357143
# station_avg_temp_c                      22.842857   25.921429   27.285714
# station_diur_temp_rng_c                  4.528571    6.357143    6.857143
# station_max_temp_c                      27.200000   30.600000   32.200000
# station_min_temp_c                      17.800000   21.700000   22.800000
# station_precip_mm                       -8.089334    6.550000   16.600000
#
#                                               75%         max
# weekofyear                              40.000000   53.000000
# ndvi_ne                                  0.129210    0.446267
# ndvi_nw                                  0.134550    0.437100
# ndvi_se                                  0.212529    0.393129
# ndvi_sw                                  0.203043    0.381420
# precipitation_amt_mm                    50.610000  287.550000
# reanalysis_air_temp_k                  299.980714  301.255714
# reanalysis_avg_temp_k                  300.053571  301.407143
# reanalysis_dew_point_temp_k            296.355714  297.467143
# reanalysis_max_air_temp_k              302.300000  303.900000
# reanalysis_min_air_temp_k              298.200000  299.500000
# reanalysis_precip_amt_kg_per_m2         40.350000  570.500000
# reanalysis_relative_humidity_percent    81.422857   87.301429
# reanalysis_sat_precip_amt_mm            50.610000  287.550000
# reanalysis_specific_humidity_g_per_kg   17.805714   19.044286
# reanalysis_tdtr_k                        2.685714    4.100000
# station_avg_temp_c                      28.192857   30.071429
# station_diur_temp_rng_c                  7.385714    9.914286
# station_max_temp_c                      32.800000   35.600000
# station_min_temp_c                      23.900000   25.600000
# station_precip_mm                       32.400000  305.900000

# %%
iq_X_train.describe().transpose()
# Out:
#                                        count        mean        std  \
# weekofyear                             364.0   26.431319  14.973924
# ndvi_ne                                364.0    0.267057   0.081455
# ndvi_nw                                364.0    0.233889   0.075983
# ndvi_se                                364.0    0.251451   0.076860
# ndvi_sw                                364.0    0.264058   0.083723
# precipitation_amt_mm                   364.0   64.413590  34.986159
# reanalysis_air_temp_k                  364.0  297.856586   1.193372
# reanalysis_avg_temp_k                  364.0  299.129271   1.346382
# reanalysis_dew_point_temp_k            364.0  295.318981   1.478115
# reanalysis_max_air_temp_k              364.0  307.190040   2.456329
# reanalysis_min_air_temp_k              364.0  292.711199   1.692738
# reanalysis_precip_amt_kg_per_m2        364.0   53.281173  50.593656
# reanalysis_relative_humidity_percent   364.0   87.876728   8.045183
# reanalysis_sat_precip_amt_mm           364.0   64.413590  34.986159
# reanalysis_specific_humidity_g_per_kg  364.0   16.916780   1.491001
# reanalysis_tdtr_k                      364.0    9.440717   2.559906
# station_avg_temp_c                     364.0   27.491899   0.923118
# station_diur_temp_rng_c                364.0   10.458942   1.532620
# station_max_temp_c                     364.0   33.926911   1.254800
# station_min_temp_c                     364.0   21.218356   1.353503
# station_precip_mm                      364.0   68.504856  66.786706
#
#                                               min         25%         50%  \
# weekofyear                               1.000000   13.750000   26.000000
# ndvi_ne                                  0.088616    0.204575    0.267829
# ndvi_nw                                  0.035860    0.178186    0.226736
# ndvi_se                                  0.029880    0.195130    0.250836
# ndvi_sw                                  0.064183    0.206225    0.261300
# precipitation_amt_mm                     0.000000   39.452500   60.850000
# reanalysis_air_temp_k                  294.635714  297.062857  297.822857
# reanalysis_avg_temp_k                  294.892857  298.217857  299.121429
# reanalysis_dew_point_temp_k            290.088571  294.344643  295.740000
# reanalysis_max_air_temp_k              300.000000  305.200000  307.200000
# reanalysis_min_air_temp_k              286.900000  291.800000  292.900000
# reanalysis_precip_amt_kg_per_m2          0.000000   21.400000   40.750000
# reanalysis_relative_humidity_percent    57.787143   83.250000   90.011429
# reanalysis_sat_precip_amt_mm             0.000000   39.452500   60.850000
# reanalysis_specific_humidity_g_per_kg   12.111429   15.879286   17.307143
# reanalysis_tdtr_k                        4.185714    7.385714    9.250000
# station_avg_temp_c                      21.400000   27.000000   27.567747
# station_diur_temp_rng_c                  5.200000    9.495000   10.433333
# station_max_temp_c                      30.100000   33.200000   33.900000
# station_min_temp_c                      14.700000   20.500000   21.400000
# station_precip_mm                        0.000000   19.000000   54.950000
#
#                                               75%         max
# weekofyear                              39.000000   53.000000
# ndvi_ne                                  0.323507    0.488400
# ndvi_nw                                  0.289986    0.428771
# ndvi_se                                  0.305611    0.473400
# ndvi_sw                                  0.321064    0.546017
# precipitation_amt_mm                    86.507500  173.450000
# reanalysis_air_temp_k                  298.588214  301.637143
# reanalysis_avg_temp_k                  300.108929  302.928571
# reanalysis_dew_point_temp_k            296.457857  297.852857
# reanalysis_max_air_temp_k              308.900000  314.000000
# reanalysis_min_air_temp_k              294.000000  295.700000
# reanalysis_precip_amt_kg_per_m2         66.557500  362.030000
# reanalysis_relative_humidity_percent    94.200000   98.457143
# reanalysis_sat_precip_amt_mm            86.507500  173.450000
# reanalysis_specific_humidity_g_per_kg   18.104643   19.731429
# reanalysis_tdtr_k                       11.317857   16.028571
# station_avg_temp_c                      28.100000   30.800000
# station_diur_temp_rng_c                 11.554167   15.800000
# station_max_temp_c                      34.525000   42.200000
# station_min_temp_c                      22.225000   24.200000
# station_precip_mm                       92.450000  543.300000

# %%
# compute the correlations
sj_correlations = sj_X_train.corr()
iq_correlations = iq_X_train.corr()

# %%
plt.rcParams["figure.figsize"] = (20,9)

# plot san juan
sj_corr_heat = sns.heatmap(sj_correlations)
plt.title('San Juan Variable Correlations')
# Out:
# Text(0.5, 1.0, 'San Juan Variable Correlations')

# %%
'''sj_rf = RandomForestRegressor(  n_estimators = 100, 
                                min_samples_leaf=25, 
                                criterion='absolute_error',
                                max_depth = 4)'''

sj_rf = RandomForestRegressor(100, min_samples_leaf=5)                        
sj_rf.fit(sj_X_train, sj_y_train)
print(mean_absolute_error(sj_y_train, sj_rf.predict(sj_X_train)))
print(mean_absolute_error(sj_y_test, sj_rf.predict(sj_X_test)))
# Out:
# 13.92337388398036
# 24.286089848755385

# %%
sj_rf.feature_importances_
# Out:
# array([0.0995262 , 0.01473657, 0.04436305, 0.6121507 , 0.02370265,
#        0.00312028, 0.00567618, 0.00865623, 0.04347681, 0.01062355,
#        0.00542264, 0.01811606, 0.0101586 , 0.00487888, 0.03385927,
#        0.01173353, 0.01423942, 0.00931073, 0.00629769, 0.0072255 ,
#        0.01272543])

# %%
plt.rcParams["figure.figsize"] = (20,9)
sj_fi = pd.DataFrame(dict(cols=sj_X_train.columns, imp=sj_rf.feature_importances_))
(   sj_fi
    .sort_values('imp', ascending=False)
    .plot('cols', 'imp', 'barh')
)
# Out:
# <AxesSubplot:ylabel='cols'>

# %%
sj_to_keep = sj_fi[sj_fi['imp'] > 0.03].cols
sj_to_keep.values
# Out:
# array(['weekofyear', 'ndvi_nw', 'ndvi_se', 'reanalysis_dew_point_temp_k',
#        'reanalysis_specific_humidity_g_per_kg'], dtype=object)

# %%
'''iq_rf =  RandomForestRegressor( n_estimators = 300, 
                                min_samples_leaf=25, 
                                criterion='absolute_error',
                                max_depth = 4)'''

iq_rf = RandomForestRegressor(100, min_samples_leaf=5)
  
iq_rf.fit(iq_X_train, iq_y_train)
print(mean_absolute_error(iq_y_train, iq_rf.predict(iq_X_train)))
print(mean_absolute_error(iq_y_test, iq_rf.predict(iq_X_test)))
# Out:
# 3.5907282993242933
# 7.3672839050563805

# %%
iq_rf.feature_importances_
# Out:
# array([0.1426272 , 0.0210194 , 0.03511149, 0.02269171, 0.03052174,
#        0.02197014, 0.03393339, 0.02623891, 0.09141661, 0.01673251,
#        0.0278487 , 0.07530955, 0.02351199, 0.01454328, 0.17461932,
#        0.03534361, 0.04564397, 0.04595895, 0.0254939 , 0.05477163,
#        0.03469201])

# %%
plt.rcParams["figure.figsize"] = (20,9)
iq_fi = pd.DataFrame(dict(cols=iq_X_train.columns, imp=iq_rf.feature_importances_))
(   iq_fi
    .sort_values('imp', ascending=False)
    .plot('cols', 'imp', 'barh')
)
# Out:
# <AxesSubplot:ylabel='cols'>

# %%
iq_to_keep = iq_fi[iq_fi['imp'] > 0.03].cols
iq_to_keep.values
# Out:
# array(['weekofyear', 'ndvi_nw', 'ndvi_sw', 'reanalysis_air_temp_k',
#        'reanalysis_dew_point_temp_k', 'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c',
#        'station_min_temp_c', 'station_precip_mm'], dtype=object)

# %%
#tain again with new features
sj_rf.fit(sj_X_train[sj_to_keep], sj_y_train)
print(mean_absolute_error(sj_y_train, sj_rf.predict(sj_X_train[sj_to_keep])))
print(mean_absolute_error(sj_y_test, sj_rf.predict(sj_X_test[sj_to_keep])))

iq_rf.fit(iq_X_train[iq_to_keep], iq_y_train)
print(mean_absolute_error(iq_y_train, iq_rf.predict(iq_X_train[iq_to_keep])))
print(mean_absolute_error(iq_y_test, iq_rf.predict(iq_X_test[iq_to_keep])))
# Out:
# 15.775775557088775
# 23.999388519188525
# 3.6915844187588647
# 7.325099953178889

# %%
figs, axes = plt.subplots(nrows=2, ncols=1)

# plot sj
sj_X_test['fitted'] = sj_rf.predict(sj_X_test[sj_to_keep])
sj_X_test.fitted.plot(ax=axes[0], label="Predictions")
sj_y_test.plot(ax=axes[0], label="Actual")

iq_X_test['fitted'] = iq_rf.predict(iq_X_test[iq_to_keep])
iq_X_test.fitted.plot(ax=axes[1], label="Predictions")
iq_y_test.plot(ax=axes[1], label="Actual")

figs.suptitle("Dengue Predicted Cases vs. Actual Cases")
figs.legend()

# %%
sj_X_test.drop('fitted',axis=1,inplace=True)
iq_X_test.drop('fitted',axis=1,inplace=True)

# %%
#submit data
sj_X_valid, iq_X_valid = get_data('dengue_features_test.csv')

# %%
sj_X_valid
# Out:
#                  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# week_start_date
# 2008-04-29               18 -0.018900 -0.018900  0.102729  0.091200
# 2008-05-06               19 -0.018000 -0.012400  0.082043  0.072314
# 2008-05-13               20 -0.001500 -0.031051  0.151083  0.091529
# 2008-05-20               21  0.052862 -0.019867  0.124329  0.125686
# 2008-05-27               22  0.056800  0.039833  0.062267  0.075914
# ...                     ...       ...       ...       ...       ...
# 2013-03-26               13 -0.087400 -0.016183  0.156343  0.105186
# 2013-04-02               14 -0.203250 -0.077833  0.204171  0.178914
# 2013-04-09               15 -0.117600 -0.008200  0.192700  0.170429
# 2013-04-16               16  0.082750  0.031200  0.135014  0.074857
# 2013-04-23               17 -0.087300 -0.048667  0.129814  0.117671
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# week_start_date
# 2008-04-29                      78.60             298.492857
# 2008-05-06                      12.56             298.475714
# 2008-05-13                       3.66             299.455714
# 2008-05-20                       0.00             299.690000
# 2008-05-27                       0.76             299.780000
# ...                               ...                    ...
# 2013-03-26                      30.34             298.670000
# 2013-04-02                       6.55             298.035714
# 2013-04-09                       0.00             299.057143
# 2013-04-16                       0.00             298.912857
# 2013-04-23                      45.47             298.067143
#
#                  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# week_start_date
# 2008-04-29                  298.550000                   294.527143
# 2008-05-06                  298.557143                   294.395714
# 2008-05-13                  299.357143                   295.308571
# 2008-05-20                  299.728571                   294.402857
# 2008-05-27                  299.671429                   294.760000
# ...                                ...                          ...
# 2013-03-26                  298.885714                   294.675714
# 2013-04-02                  298.157143                   294.628571
# 2013-04-09                  299.328571                   294.948571
# 2013-04-16                  299.064286                   294.678571
# 2013-04-23                  298.042857                   294.132857
#
#                  reanalysis_max_air_temp_k  ...  \
# week_start_date                             ...
# 2008-04-29                           301.1  ...
# 2008-05-06                           300.8  ...
# 2008-05-13                           302.2  ...
# 2008-05-20                           303.0  ...
# 2008-05-27                           302.3  ...
# ...                                    ...  ...
# 2013-03-26                           301.3  ...
# 2013-04-02                           301.5  ...
# 2013-04-09                           301.5  ...
# 2013-04-16                           300.9  ...
# 2013-04-23                           300.2  ...
#
#                  reanalysis_precip_amt_kg_per_m2  \
# week_start_date
# 2008-04-29                                 25.37
# 2008-05-06                                 21.83
# 2008-05-13                                  4.12
# 2008-05-20                                  2.20
# 2008-05-27                                  4.36
# ...                                          ...
# 2013-03-26                                  2.55
# 2013-04-02                                 64.30
# 2013-04-09                                  0.70
# 2013-04-16                                  1.40
# 2013-04-23                                 19.90
#
#                  reanalysis_relative_humidity_percent  \
# week_start_date
# 2008-04-29                                  78.781429
# 2008-05-06                                  78.230000
# 2008-05-13                                  78.270000
# 2008-05-20                                  73.015714
# 2008-05-27                                  74.084286
# ...                                               ...
# 2013-03-26                                  78.780000
# 2013-04-02                                  81.650000
# 2013-04-09                                  78.285714
# 2013-04-16                                  77.674286
# 2013-04-23                                  79.045714
#
#                  reanalysis_sat_precip_amt_mm  \
# week_start_date
# 2008-04-29                              78.60
# 2008-05-06                              12.56
# 2008-05-13                               3.66
# 2008-05-20                               0.00
# 2008-05-27                               0.76
# ...                                       ...
# 2013-03-26                              30.34
# 2013-04-02                               6.55
# 2013-04-09                               0.00
# 2013-04-16                               0.00
# 2013-04-23                              45.47
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# week_start_date
# 2008-04-29                                   15.918571           3.128571
# 2008-05-06                                   15.791429           2.571429
# 2008-05-13                                   16.674286           4.428571
# 2008-05-20                                   15.775714           4.342857
# 2008-05-27                                   16.137143           3.542857
# ...                                                ...                ...
# 2013-03-26                                   15.985714           3.314286
# 2013-04-02                                   15.881429           2.828571
# 2013-04-09                                   16.212857           3.171429
# 2013-04-16                                   15.965714           3.042857
# 2013-04-23                                   15.451429           2.342857
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# week_start_date
# 2008-04-29                26.528571                 7.057143
# 2008-05-06                26.071429                 5.557143
# 2008-05-13                27.928571                 7.785714
# 2008-05-20                28.057143                 6.271429
# 2008-05-27                27.614286                 7.085714
# ...                             ...                      ...
# 2013-03-26                27.542857                 7.942857
# 2013-04-02                26.642857                 6.642857
# 2013-04-09                27.914286                 8.114286
# 2013-04-16                27.728571                 6.942857
# 2013-04-23                26.442857                 6.742857
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm
# week_start_date
# 2008-04-29                     33.3                21.7               75.2
# 2008-05-06                     30.0                22.2               34.3
# 2008-05-13                     32.8                22.8                3.0
# 2008-05-20                     33.3                24.4                0.3
# 2008-05-27                     33.3                23.3               84.1
# ...                             ...                 ...                ...
# 2013-03-26                     33.9                22.8                3.5
# 2013-04-02                     33.3                22.8               17.6
# 2013-04-09                     32.8                23.3                9.4
# 2013-04-16                     31.7                23.9               22.9
# 2013-04-23                     31.1                21.7               47.5
#
# [260 rows x 21 columns]

# %%
iq_X_valid
# Out:
#                  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# week_start_date
# 2010-07-02               26  0.183783  0.142500  0.225129  0.150214
# 2010-07-09               27  0.291657  0.272267  0.330700  0.320914
# 2010-07-16               28  0.208543  0.366457  0.212629  0.255514
# 2010-07-23               29  0.089286  0.063214  0.122057  0.081957
# 2010-07-30               30  0.306100  0.327683  0.250086  0.267914
# ...                     ...       ...       ...       ...       ...
# 2013-05-28               22  0.301471  0.380029  0.280629  0.383186
# 2013-06-04               23  0.247600  0.296343  0.285371  0.350357
# 2013-06-11               24  0.238729  0.251029  0.252586  0.249771
# 2013-06-18               25  0.310429  0.302700  0.406614  0.403943
# 2013-06-25               26  0.339467  0.240071  0.356943  0.273600
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# week_start_date
# 2010-07-02                      82.29             297.648571
# 2010-07-09                      25.30             298.224286
# 2010-07-16                      62.14             297.955714
# 2010-07-23                      47.80             295.715714
# 2010-07-30                      56.30             298.502857
# ...                               ...                    ...
# 2013-05-28                      41.12             297.774286
# 2013-06-04                      71.52             297.167143
# 2013-06-11                      78.96             295.831429
# 2013-06-18                      39.54             295.778571
# 2013-06-25                      51.80             297.372857
#
#                  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# week_start_date
# 2010-07-02                  299.214286                   296.118571
# 2010-07-09                  299.464286                   294.831429
# 2010-07-16                  298.964286                   296.417143
# 2010-07-23                  296.642857                   293.638571
# 2010-07-30                  300.000000                   293.892857
# ...                                ...                          ...
# 2013-05-28                  298.964286                   295.638571
# 2013-06-04                  298.328571                   295.845714
# 2013-06-11                  296.607143                   294.894286
# 2013-06-18                  297.400000                   293.648571
# 2013-06-25                  299.000000                   294.615714
#
#                  reanalysis_max_air_temp_k  ...  \
# week_start_date                             ...
# 2010-07-02                           307.9  ...
# 2010-07-09                           307.7  ...
# 2010-07-16                           306.4  ...
# 2010-07-23                           306.4  ...
# 2010-07-30                           308.1  ...
# ...                                    ...  ...
# 2013-05-28                           305.5  ...
# 2013-06-04                           306.3  ...
# 2013-06-11                           304.6  ...
# 2013-06-18                           305.9  ...
# 2013-06-25                           307.3  ...
#
#                  reanalysis_precip_amt_kg_per_m2  \
# week_start_date
# 2010-07-02                                 34.11
# 2010-07-09                                  9.10
# 2010-07-16                                 61.09
# 2010-07-23                                 19.60
# 2010-07-30                                 18.93
# ...                                          ...
# 2013-05-28                                 67.60
# 2013-06-04                                 45.70
# 2013-06-11                                 45.22
# 2013-06-18                                  4.70
# 2013-06-25                                 27.80
#
#                  reanalysis_relative_humidity_percent  \
# week_start_date
# 2010-07-02                                  92.581429
# 2010-07-09                                  83.885714
# 2010-07-16                                  92.057143
# 2010-07-23                                  88.970000
# 2010-07-30                                  78.610000
# ...                                               ...
# 2013-05-28                                  89.990000
# 2013-06-04                                  93.891429
# 2013-06-11                                  94.967143
# 2013-06-18                                  89.057143
# 2013-06-25                                  87.030000
#
#                  reanalysis_sat_precip_amt_mm  \
# week_start_date
# 2010-07-02                              82.29
# 2010-07-09                              25.30
# 2010-07-16                              62.14
# 2010-07-23                              47.80
# 2010-07-30                              56.30
# ...                                       ...
# 2013-05-28                              41.12
# 2013-06-04                              71.52
# 2013-06-11                              78.96
# 2013-06-18                              39.54
# 2013-06-25                              51.80
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# week_start_date
# 2010-07-02                                   17.654286           9.428571
# 2010-07-09                                   16.320000          10.157143
# 2010-07-16                                   18.030000           9.557143
# 2010-07-23                                   15.394286           7.828571
# 2010-07-30                                   15.468571          11.771429
# ...                                                ...                ...
# 2013-05-28                                   17.185714          10.100000
# 2013-06-04                                   17.448571           9.657143
# 2013-06-11                                   16.410000           7.385714
# 2013-06-18                                   15.137143           8.228571
# 2013-06-25                                   16.148571          11.542857
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# week_start_date
# 2010-07-02                   27.440                   10.760
# 2010-07-09                   27.025                    9.625
# 2010-07-16                   26.950                   10.350
# 2010-07-23                   26.900                    9.700
# 2010-07-30                   27.050                   11.850
# ...                             ...                      ...
# 2013-05-28                   27.400                    9.050
# 2013-06-04                   27.520                   10.720
# 2013-06-11                   27.200                   10.075
# 2013-06-18                   26.700                    8.480
# 2013-06-25                   27.350                    9.675
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm
# week_start_date
# 2010-07-02                     33.8                21.5               11.2
# 2010-07-09                     33.0                21.2                8.9
# 2010-07-16                     33.4                21.6               22.6
# 2010-07-23                     33.3                14.2                4.8
# 2010-07-30                     33.5                16.9                3.0
# ...                             ...                 ...                ...
# 2013-05-28                     32.6                21.8               33.0
# 2013-06-04                     33.8                21.4               68.0
# 2013-06-11                     32.6                21.6               93.2
# 2013-06-18                     32.2                21.8               34.1
# 2013-06-25                     32.6                22.0               14.9
#
# [156 rows x 21 columns]

# %%
sj_predictions = sj_rf.predict(sj_X_valid[sj_to_keep]).astype(int)
iq_predictions = iq_rf.predict(iq_X_valid[iq_to_keep]).astype(int)

submission = pd.read_csv("submission_format.csv",
                         index_col=[0, 1, 2])

submission.total_cases = np.concatenate([sj_predictions, iq_predictions])
#submission.to_csv("benchmark.csv")

# %%
print('sj', mean_absolute_error(sj_y_test, sj_rf.predict(sj_X_test[sj_to_keep])))
print('iq', mean_absolute_error(iq_y_test, iq_rf.predict(iq_X_test[iq_to_keep])))
# Out:
# sj 23.999388519188525
# iq 7.325099953178889

# %%
plt.plot(sj_predictions)

# %%
plt.plot(iq_predictions)
